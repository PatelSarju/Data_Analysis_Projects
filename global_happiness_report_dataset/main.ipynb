# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
import matplotlib

# %%
# load the dataset
global_happiness_data=pd.read_csv('2015.csv')

# %%
global_happiness_data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
global_happiness_data.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
# create pivot table between economy and happiness score
economy_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Economy (GDP per Capita)',aggfunc='mean')

# create pivot table between economy and happiness rank
economy_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Economy (GDP per Capita)',aggfunc='mean')

# create pivot table between family and happiness score
family_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Family',aggfunc='mean')

# create pivot table between family and happiness rank
family_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Family',aggfunc='mean')

# create pivot table between country and happiness score
country_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Country',aggfunc='mean')

# create pivot table between country and happiness rank
country_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Country',aggfunc='mean')

# create pivot table between region and happiness score
region_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Region',aggfunc='mean')

# create pivot table between region and happiness rank
region_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Region',aggfunc='mean')

# create pivot table between government and happiness score
government_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Trust (Government Corruption)',aggfunc='mean')

# create pivot table between government and happiness rank
government_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Trust (Government Corruption)',aggfunc='mean')

# create pivot table between health and happiness score
health_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Health (Life Expectancy)',aggfunc='mean')

# create pivot table between health and happiness rank
health_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Health (Life Expectancy)',aggfunc='mean')

# create pivot table between freedom and happiness score
freedom_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Freedom',aggfunc='mean')

# create pivot table between freedom and happiness rank
freedom_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Freedom',aggfunc='mean')

# create pivot table between generosity and happiness score
generosity_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Generosity',aggfunc='mean')

# create pivot table between generosity and happiness rank
generosity_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Generosity',aggfunc='mean')

# create pivot table between Dystopia Residual and happiness score
Dystopia_Residual_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index='Dystopia Residual',aggfunc='mean')

# create pivot table between Dystopia Residual and happiness rank
Dystopia_Residual_and_happiness_rank=pd.pivot_table(global_happiness_data,values='Happiness Rank',index='Dystopia Residual',aggfunc='mean')

# create pivot table between region and economy
region_and_economy=pd.pivot_table(global_happiness_data,values='Economy (GDP per Capita)',index='Region',aggfunc='mean')

# create pivot table between family and economy
family_and_economy=pd.pivot_table(global_happiness_data,values='Economy (GDP per Capita)',index='Family',aggfunc='mean')

# create pivot table between government and economy
government_and_economy=pd.pivot_table(global_happiness_data,values='Economy (GDP per Capita)',index='Trust (Government Corruption)',aggfunc='mean')

# create pivot table between economy, family and happiness score
family_economy_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index=['Family','Economy (GDP per Capita)'],aggfunc='mean')

# create pivot table between economy, government and happiness score
government_economy_and_happiness_score=pd.pivot_table(global_happiness_data,values='Happiness Score',index=['Trust (Government Corruption)','Economy (GDP per Capita)'],aggfunc='mean')

# %%
def create_scatterplot(data, start, end, xlabel='None', ylabel='None', title='Data', fig_width=20, fig_height=10, colormap='red'):
    """
    Creates a scatter plot for a specified subset of data, with the color of the points 
    based on the values of the data.

    Args:
        data (pandas.DataFrame): The dataset containing the data to plot.
        start (int): The starting index for selecting the subset of the data.
        end (int): The ending index for selecting the subset of the data.
        xlabel (str, optional): The label for the x-axis. Default is 'None'.
        ylabel (str, optional): The label for the y-axis. Default is 'None'.
        title (str, optional): The title of the plot. Default is 'Data'.
        fig_width (int, optional): The width of the figure. Default is 20.
        fig_height (int, optional): The height of the figure. Default is 10.
        colormap (str, optional): The colormap to use for coloring the points. Default is 'red'.

    Returns:
        None: Displays the scatter plot.
    """

    subset = data.iloc[start:end]
    plt.figure(figsize=(fig_width, fig_height))
    values = subset.columns[0]
    
    norm = mcolors.Normalize(vmin=subset[values].min(), vmax=subset[values].max())
    cmap = matplotlib.colormaps[colormap]  
    color = [cmap(norm(value)) for value in subset[values]]
    
    sns.scatterplot(data=subset, x=subset.index, y=subset[values], palette=color,hue=subset.index)
    plt.title(title, fontweight='bold')
    plt.xlabel(xlabel, fontweight='bold')
    plt.ylabel(ylabel, fontweight='bold')
    plt.show()

# %%
create_scatterplot(economy_and_happiness_score,0,158,'Economy (GDP)','Happiness Score','Happiness Score By Economy',15,10,'viridis')

# %%
create_scatterplot(economy_and_happiness_rank,0,158,'Economy (GDP)','Happiness Rank','Happiness Rank According Economy',15,10,'icefire')

# %%
create_scatterplot(family_and_happiness_score,0,158,'Family','Happiness Score','Happiness Score By Family',15,10,'rainbow')

# %%
create_scatterplot(family_and_happiness_rank,0,158,'Family','Happiness Rank','Happiness Rank By Family',15,10,'seismic')

# %%
def create_barplot(data, start, end, xlabel='None', ylabel='None', title='Data', fig_width=20, fig_height=10, colormap='red'):
    """
    Creates a bar plot for the specified subset of the data, with color gradient based on the values.

    Args:
        data (pandas.DataFrame): The dataset containing the data to plot.
        start (int): The starting index for selecting the subset of the data.
        end (int): The ending index for selecting the subset of the data.
        xlabel (str, optional): Label for the x-axis. Default is 'None'.
        ylabel (str, optional): Label for the y-axis. Default is 'None'.
        title (str, optional): Title of the plot. Default is 'Covid Data'.
        fig_width (int, optional): Width of the figure. Default is 20.
        fig_height (int, optional): Height of the figure. Default is 10.
        colormap (str, optional): The colormap to use for coloring the bars. Default is 'red'.

    Returns:
        None: Displays the bar plot.
    """
    subset = data.iloc[start:end]
    plt.figure(figsize=(fig_width, fig_height))
    values = subset.columns[0]
    
    norm = mcolors.Normalize(vmin=subset[values].min(), vmax=subset[values].max())
    cmap = matplotlib.colormaps[colormap]  
    color = [cmap(norm(value)) for value in subset[values]]
    
    sns.barplot(data=subset, x=subset.index, y=subset[values], palette=color, hue=subset.index)
    plt.title(title, fontweight='bold')
    plt.xlabel(xlabel, fontweight='bold')
    plt.ylabel(ylabel, fontweight='bold')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
create_barplot(country_and_happiness_score,0,50,'Country Name','Happiness Score','Happiness Score Country Wise',15,10,'coolwarm')

# %%
create_barplot(country_and_happiness_score,50,100,'Country Name','Happiness Score','Happiness Score Country Wise',15,10,'coolwarm')

# %%
create_barplot(country_and_happiness_score,100,158,'Country Name','Happiness Score','Happiness Score Country Wise',15,10,'coolwarm')

# %%
create_barplot(country_and_happiness_rank,0,50,'Country Name','Happiness Rank','Happiness Rank Country Wise',15,10,'brg')

# %%
create_barplot(country_and_happiness_rank,50,100,'Country Name','Happiness Rank','Happiness Rank Country Wise',15,10,'brg')

# %%
create_barplot(country_and_happiness_rank,100,158,'Country Name','Happiness Rank','Happiness Rank Country Wise',15,10,'brg')

# %%
def create_lineplot(data, start, end, xlabel='None', ylabel='None', title='Data', fig_width=20, fig_height=10, color='red'):
    """
    Creates a bar plot for the specified subset of the data, with color gradient based on the values.

    Args:
        data (pandas.DataFrame): The dataset containing the data to plot.
        start (int): The starting index for selecting the subset of the data.
        end (int): The ending index for selecting the subset of the data.
        xlabel (str, optional): Label for the x-axis. Default is 'None'.
        ylabel (str, optional): Label for the y-axis. Default is 'None'.
        title (str, optional): Title of the plot. Default is 'Covid Data'.
        fig_width (int, optional): Width of the figure. Default is 20.
        fig_height (int, optional): Height of the figure. Default is 10.
        colormap (str, optional): The colormap to use for coloring the bars. Default is 'red'.

    Returns:
        None: Displays the bar plot.
    """
    subset = data.iloc[start:end]
    plt.figure(figsize=(fig_width, fig_height))
    values = subset.columns[0]
    
    sns.lineplot(data=subset, x=subset.index, y=subset[values],marker='o',markersize=5, color=color, hue=None)
    plt.title(title, fontweight='bold')
    plt.xlabel(xlabel, fontweight='bold')
    plt.ylabel(ylabel, fontweight='bold')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
create_scatterplot(government_and_happiness_score,0,158,'Government','Happiness Score','Happiness Score Government Wise',15,10,'autumn')

# %%
create_scatterplot(government_and_happiness_rank,0,158,'Government','Happiness Rank','Happiness Rank Government Wise',15,10,'ocean')

# %%
create_scatterplot(health_and_happiness_score,0,158,'Health Ratio','Happiness Score','Happiness Score Health Ratio Wise',15,10,'coolwarm')

# %%
create_scatterplot(health_and_happiness_rank,0,158,'Health Ratio','Happiness Rank','Happiness Rank Health Ratio Wise',15,10,'rocket')

# %%
create_scatterplot(government_and_economy,0,158,'Government','Economy','Economy Government Wise',15,10,'hsv')

# %%
create_scatterplot(freedom_and_happiness_score,0,158,'Freedom Rate','Happiness Score','Happiness Score Based On Freedom Rate',15,10,'vlag')

# %%
create_scatterplot(freedom_and_happiness_rank,0,158,'Freedom Rate','Happiness Rank','Happiness Rank Based On Freedom Rate',15,10,'rocket')

# %%
def create_pieplot(data,start,end,title='Data', fig_width=20, fig_height=10, colormap='red'):
    """
    Creates a pie plot for a specified subset of data, with the colors of the slices 
    mapped based on the values of the data.

    Args:
        data (pandas.DataFrame): The dataset containing the data to plot.
        start (int): The starting index for selecting the subset of the data.
        end (int): The ending index for selecting the subset of the data.
        title (str, optional): The title of the plot. Default is 'Data'.
        fig_width (int, optional): The width of the figure. Default is 20.
        fig_height (int, optional): The height of the figure. Default is 10.
        colormap (str, optional): The colormap to use for coloring the pie slices. Default is 'Reds'.

    Returns:
        None: Displays the pie plot.
    """
    subset = data.iloc[start:end]
    plt.figure(figsize=(fig_width, fig_height))
    values = subset[subset.columns[0]]
    
    norm = mcolors.Normalize(vmin=values.min(), vmax=values.max())
    cmap = matplotlib.cm.get_cmap(colormap)  
    color = [cmap(norm(value)) for value in values]
    
    plt.pie(values, labels=subset.index, autopct='%1.1f%%', colors=color, startangle=0,
            pctdistance=0.75, labeldistance=1.1)
    plt.title(title, fontweight='bold')
    plt.axis('equal')
    plt.show()

# %%
create_pieplot(region_and_economy,0,10,'Region and Its Economy',5,5,'winter')
# Out:
# C:\Users\sarju\AppData\Local\Temp\ipykernel_13520\3453224930.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap(colormap)

# %%
create_pieplot(region_and_happiness_rank,0,10,'Region and Its Happiness Rank',5,5,'YlGnBu')
# Out:
# C:\Users\sarju\AppData\Local\Temp\ipykernel_13520\3453224930.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap(colormap)

# %%
create_scatterplot(generosity_and_happiness_score,0,158,'Generosity','Happiness Score','Happiness Score Based On Generosity',15,10,'inferno')

# %%
create_scatterplot(generosity_and_happiness_rank,0,158,'Generosity','Happiness Rank','Happiness Rank Based On Generosity',15,10,'spring')

# %%
create_scatterplot(Dystopia_Residual_and_happiness_score,0,158,'Dystopia Residual','Happiness Score','Happiness Score Based On Dystopia Residual',15,10,'autumn')

# %%
create_scatterplot(Dystopia_Residual_and_happiness_rank,0,158,'Dystopia Residual','Happiness Rank','Happiness Rank Based On Dystopia Residual',15,10,'BuPu')

# %%
create_scatterplot(family_and_economy,0,158,'Family','Economy','Economy Family Wise',15,10,'YlGn')

# %%
# Top 5 country with highest happiness score
country_and_score=country_and_happiness_score.sort_values(ascending=False,by='Happiness Score')
create_pieplot(country_and_score,0,5,'Top 5 Country With Highest Happiness Score',4,4,'plasma')
# Out:
# C:\Users\sarju\AppData\Local\Temp\ipykernel_1484\3453224930.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap(colormap)

# %%
# Top 5 country with highest happiness score
country_and_rank=country_and_happiness_rank.sort_values(ascending=False,by='Happiness Rank')
create_pieplot(country_and_rank,0,5,'Top 5 Country With Highest Happiness Rank',4,4,'YlGnBu')
# Out:
# C:\Users\sarju\AppData\Local\Temp\ipykernel_1484\3453224930.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap(colormap)
